# %%
import pandas as pd

df=pd.read_csv('students.csv', index_col=0)
df

# %%
df=pd.read_excel('students.xlsx', index_col=0)
df.head()  #預設是5，改成顯示5筆資料
# Out:
#      國文  英文  數學  自然  社會
# 余宗儒  73  82  62  54  86
# 劉佳佩  95  70  56  78  52
# 沈心利  75  58  55  59  96
# 游詩亞  55  56  63  96  95
# 彭茹靖  65  50  62  78  57

# %% [markdown]
# ### **-透過欄選取**
# ### **-透過列選取**

# %%
# 透過欄選取
# 單欄選取
df['國文']  #series
# Out:
# 余宗儒     73
# 劉佳佩     95
# 沈心利     75
# 游詩亞     55
# 彭茹靖     65
# 張軒宸    100
# 朱惠儀     94
# 鄭孟芳     94
# 黃佩芬    100
# 楊易政     94
# 潘英迪     54
# 劉慧君     98
# 陳信念     98
# 謝佳穎     66
# 楊韻如     54
# 程玫靖     73
# 黃彥孝     80
# 王志謙     64
# 陳倩潔     89
# 吳俐芷     87
# 黃健發     96
# 方雅慧     54
# 蘇凡菁     50
# 王士銘     71
# 陳逸凡     99
# 白世宏     54
# 余月修     59
# 胡淑貞     79
# 陳怡容     70
# 李慈啟     89
# 林淑安     84
# 蔡世馨     67
# 鄭佳玲     78
# 陳怡伶     76
# 金宜芳     51
# 游倫城     55
# 吳麗卿     71
# 李慶亮     57
# 王柏聖     54
# 賴心怡     66
# 盧必妍     99
# 吳志宣     94
# 鄧亭聿     89
# 白美珍     80
# 王人仰     91
# 陳得映     67
# 張婕妤     55
# 周家銘     98
# 李湘婷     94
# 唐雪豪     59
# Name: 國文, dtype: int64

# %%
# 多欄選取
df[['國文','英文']]  #dataframe (裡面有兩個series)
# Out:
#       國文   英文
# 余宗儒   73   82
# 劉佳佩   95   70
# 沈心利   75   58
# 游詩亞   55   56
# 彭茹靖   65   50
# 張軒宸  100   85
# 朱惠儀   94   56
# 鄭孟芳   94   68
# 黃佩芬  100   60
# 楊易政   94   82
# 潘英迪   54   77
# 劉慧君   98   94
# 陳信念   98   87
# 謝佳穎   66   91
# 楊韻如   54   90
# 程玫靖   73   83
# 黃彥孝   80   86
# 王志謙   64   78
# 陳倩潔   89   86
# 吳俐芷   87   56
# 黃健發   96   61
# 方雅慧   54   78
# 蘇凡菁   50   99
# 王士銘   71   66
# 陳逸凡   99   92
# 白世宏   54   98
# 余月修   59   72
# 胡淑貞   79   90
# 陳怡容   70   79
# 李慈啟   89   69
# 林淑安   84   68
# 蔡世馨   67   72
# 鄭佳玲   78   66
# 陳怡伶   76   87
# 金宜芳   51   87
# 游倫城   55   97
# 吳麗卿   71  100
# 李慶亮   57   74
# 王柏聖   54   75
# 賴心怡   66   66
# 盧必妍   99   59
# 吳志宣   94   80
# 鄧亭聿   89   87
# 白美珍   80   63
# 王人仰   91   56
# 陳得映   67   51
# 張婕妤   55   75
# 周家銘   98   51
# 李湘婷   94   56
# 唐雪豪   59   66
